# %% [markdown]
# # DMET / projection walkthrough
#
# Projection trace smoke config: `configs/example_h2_projection_trace.yaml`.
#
# **Deps:** `pip install -e ".[chem]"` (PySCF).

# %%
from pathlib import Path

from qchem_stack.config import load_experiment_config

CONFIG = Path("../configs/example_h2_projection_trace.yaml").resolve()
cfg = load_experiment_config(CONFIG)
print("embedding.mode:", cfg.embedding.mode)
proj = getattr(cfg.embedding, "projection", None)
print("projection spec:", proj)

# %%
from qchem_stack.orchestration.pipeline import run_pipeline_from_config

out = run_pipeline_from_config(CONFIG)
handoff = (out.get("repro") or {}).get("pre_quantum_handoff_v1")
print("stages:", (out.get("repro") or {}).get("run_summary", {}).get("stages_completed", [])[-3:])
print("handoff schema:", handoff.get("schema") if isinstance(handoff, dict) else None)
