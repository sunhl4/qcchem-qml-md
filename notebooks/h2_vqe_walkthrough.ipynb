# %% [markdown]
# # H2 VQE walkthrough
#
# Minimal runnable cells for `configs/example_h2.yaml`.
#
# **Deps:** `pip install -e ".[chem]"` (PySCF).

# %%
from pathlib import Path

from qchem_stack.orchestration.pipeline import run_pipeline_from_config

CONFIG = Path("../configs/example_h2.yaml").resolve()
assert CONFIG.is_file(), CONFIG

# %%
out = run_pipeline_from_config(CONFIG)
print("experiment_id:", out.get("experiment_id"))
print("scf_energy:", out.get("scf_energy"))
print("energy_after_variational:", out.get("energy_after_variational"))
