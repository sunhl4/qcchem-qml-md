# %% [markdown]
# # VQD excited-state walkthrough
#
# Runs `configs/example_h2_vqd_uccsd.yaml` (deflation / UCCSD VQD).
#
# **Deps:** `pip install -e ".[chem]"`

# %%
from pathlib import Path

from qchem_stack.orchestration.pipeline import run_pipeline_from_config

CONFIG = Path("../configs/example_h2_vqd_uccsd.yaml").resolve()
out = run_pipeline_from_config(CONFIG)
print("energy_after_variational", out.get("energy_after_variational"))
print("vqd keys", [k for k in out if "vqd" in k.lower()])
